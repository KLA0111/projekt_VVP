# %%
from bludiste import *

# %% [markdown]
# Obecny postup pro hledani cesty v danem bludiste:

# %%
maze_test = load_maze("data/maze_3.csv")
show_maze(maze_test)
path = get_path(maze_test)
show_maze(maze_test, path)

# %% [markdown]
# Postup fungovani get_path vypada takto: nejprve udelame matice incidence, pak projdeme ji celou, pak najdeme nejkrasti cestu z verhniho leveho vrcholu fo dolniho praveho.

# %%
incidence = get_incindence(maze_test)
d = dijkstra(incidence)
path = get_path_dijkstra(d, incidence)
show_maze(maze_test, path)

# %% [markdown]
# Muzeme ukazat matice incindecnosti pro dane bludiste:

# %%
incidence = get_incindence(maze_test)

fig, ax = plt.subplots()
ax.imshow(incidence, cmap='binary')
plt.show()

# %% [markdown]
# Priklady generace nahodnych bludist:

# %%
sidewinder = generate_maze(57, pattern='sidewinder')
show_maze(sidewinder)
path = get_path(sidewinder)
show_maze(sidewinder, path)

# %% [markdown]
# Pro slalom muzeme zadatat pravdepodobnost pro steny. 0 - ani jedna stena, 1 - maximum sten

# %%
slalom = generate_maze(57, pattern='slalom', p=0.7)
show_maze(slalom)
path = get_path(slalom)
show_maze(slalom, path)

# %%
empty = generate_maze(57, pattern='empty')
show_maze(empty)
path = get_path(empty)
show_maze(empty, path)

# %% [markdown]
# Ukazeme prace z save_maze:

# %%
new_maze = generate_maze(17, pattern='sidewinder')
show_maze(new_maze)
save_maze('data/sidewinder.csv', new_maze)
new_maze_loaded = load_maze('data/sidewinder.csv')
show_maze(new_maze_loaded)
